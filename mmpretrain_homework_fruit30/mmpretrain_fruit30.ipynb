# %% [markdown]
# ## 划分数据集

# %%
import os
import random
import shutil

os.chdir('mmpretrain')
#源数据集路径和目标数据集路径
path_source = 'data/fruit30_train'
path_target = 'data/fruit30_test'
 
#参数：源路径、目标路径和测试集所占比例
def seperate(path_source, path_target, percent):
    #生成包含path_source下所有目录名的列表
    categories = os.listdir(path_source)
    for name in categories:
        #在path_target下建立相同名称的子目录
        os.makedirs(os.path.join(path_target, name))
        #生成包含子目录下所有图片的列表
        nums = os.listdir(os.path.join(path_source, name))
        #随机按比例抽取一部分图片
        nums_target = random.sample(nums, int(len(nums)*percent))
        #把图片剪切到目标路径
        for pic in nums_target:
            shutil.move(os.path.join(path_source, name, pic), os.path.join(path_target, name, pic))

# %%
#执行完成后，path_source为训练集，path_target为测试集。
seperate(path_source, path_target, 0.3)

# %%
# !pwd
# Out:
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain

# %% [markdown]
# ## 模型训练

# %%
# !mim train mmpretrain projects/fruits/resnet50_fruits.py --work-dir=./fruit30_exp
# Out:
# Training command is /root/miniconda3/bin/python /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/train.py projects/fruits/resnet50_fruits.py --launcher none --work-dir=./fruit30_exp.
# 06/10 13:36:00 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 1625880158
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
#     PyTorch: 1.10.0+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.2
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.11.1+cu113
#     OpenCV: 4.7.0
#     MMEngine: 0.7.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/10 13:36:01 - mmengine - INFO - Config:
# model = dict(
#     type='ImageClassifier',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch'),
#     neck=dict(type='GlobalAveragePooling'),
#     head=dict(
#         type='LinearClsHead',
#         num_classes=30,
#         in_channels=2048,
#         loss=dict(type='CrossEntropyLoss', loss_weight=1.0),
#         topk=(1, 5),
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth'
#         )))
# dataset_type = 'CustomDataset'
# data_preprocessor = dict(
#     num_classes=1000,
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='RandomResizedCrop', scale=224),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='ResizeEdge', scale=256, edge='short'),
#     dict(type='CenterCrop', crop_size=224),
#     dict(type='PackInputs')
# ]
# train_dataloader = dict(
#     pin_memory=True,
#     persistent_workers=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='RandomResizedCrop', scale=224),
#             dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=True))
# val_dataloader = dict(
#     pin_memory=True,
#     persistent_workers=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_test',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# val_evaluator = dict(type='Accuracy', topk=(1, 5))
# test_dataloader = dict(
#     pin_memory=True,
#     persistent_workers=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_test',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# test_evaluator = dict(type='Accuracy', topk=(1, 5))
# optim_wrapper = dict(
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0001))
# param_scheduler = dict(
#     type='MultiStepLR', by_epoch=True, milestones=[30, 60, 90], gamma=0.1)
# train_cfg = dict(by_epoch=True, max_epochs=20, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# auto_scale_lr = dict(base_batch_size=256)
# default_scope = 'mmpretrain'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook', interval=1, max_keep_ckpts=5, save_best='auto'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='VisualizationHook', enable=False))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='UniversalVisualizer', vis_backends=[dict(type='LocalVisBackend')])
# log_level = 'INFO'
# load_from = None
# resume = False
# randomness = dict(seed=None, deterministic=False)
# launcher = 'none'
# work_dir = './fruit30_exp'
#
# 06/10 13:36:09 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/10 13:36:09 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 06/10 13:36:11 - mmengine - INFO - load model from: https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth
# 06/10 13:36:11 - mmengine - INFO - Loads checkpoint by http backend from path: https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth
# Downloading: "https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth" to /root/.cache/torch/hub/checkpoints/resnet50_8xb32_in1k_20210831-ea4938fc.pth
# 100%|██████████████████████████████████████| 97.8M/97.8M [00:11<00:00, 9.05MB/s]
# 06/10 13:36:23 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: backbone.conv1.weight, backbone.bn1.weight, backbone.bn1.bias, backbone.bn1.running_mean, backbone.bn1.running_var, backbone.bn1.num_batches_tracked, backbone.layer1.0.conv1.weight, backbone.layer1.0.bn1.weight, backbone.layer1.0.bn1.bias, backbone.layer1.0.bn1.running_mean, backbone.layer1.0.bn1.running_var, backbone.layer1.0.bn1.num_batches_tracked, backbone.layer1.0.conv2.weight, backbone.layer1.0.bn2.weight, backbone.layer1.0.bn2.bias, backbone.layer1.0.bn2.running_mean, backbone.layer1.0.bn2.running_var, backbone.layer1.0.bn2.num_batches_tracked, backbone.layer1.0.conv3.weight, backbone.layer1.0.bn3.weight, backbone.layer1.0.bn3.bias, backbone.layer1.0.bn3.running_mean, backbone.layer1.0.bn3.running_var, backbone.layer1.0.bn3.num_batches_tracked, backbone.layer1.0.downsample.0.weight, backbone.layer1.0.downsample.1.weight, backbone.layer1.0.downsample.1.bias, backbone.layer1.0.downsample.1.running_mean, backbone.layer1.0.downsample.1.running_var, backbone.layer1.0.downsample.1.num_batches_tracked, backbone.layer1.1.conv1.weight, backbone.layer1.1.bn1.weight, backbone.layer1.1.bn1.bias, backbone.layer1.1.bn1.running_mean, backbone.layer1.1.bn1.running_var, backbone.layer1.1.bn1.num_batches_tracked, backbone.layer1.1.conv2.weight, backbone.layer1.1.bn2.weight, backbone.layer1.1.bn2.bias, backbone.layer1.1.bn2.running_mean, backbone.layer1.1.bn2.running_var, backbone.layer1.1.bn2.num_batches_tracked, backbone.layer1.1.conv3.weight, backbone.layer1.1.bn3.weight, backbone.layer1.1.bn3.bias, backbone.layer1.1.bn3.running_mean, backbone.layer1.1.bn3.running_var, backbone.layer1.1.bn3.num_batches_tracked, backbone.layer1.2.conv1.weight, backbone.layer1.2.bn1.weight, backbone.layer1.2.bn1.bias, backbone.layer1.2.bn1.running_mean, backbone.layer1.2.bn1.running_var, backbone.layer1.2.bn1.num_batches_tracked, backbone.layer1.2.conv2.weight, backbone.layer1.2.bn2.weight, backbone.layer1.2.bn2.bias, backbone.layer1.2.bn2.running_mean, backbone.layer1.2.bn2.running_var, backbone.layer1.2.bn2.num_batches_tracked, backbone.layer1.2.conv3.weight, backbone.layer1.2.bn3.weight, backbone.layer1.2.bn3.bias, backbone.layer1.2.bn3.running_mean, backbone.layer1.2.bn3.running_var, backbone.layer1.2.bn3.num_batches_tracked, backbone.layer2.0.conv1.weight, backbone.layer2.0.bn1.weight, backbone.layer2.0.bn1.bias, backbone.layer2.0.bn1.running_mean, backbone.layer2.0.bn1.running_var, backbone.layer2.0.bn1.num_batches_tracked, backbone.layer2.0.conv2.weight, backbone.layer2.0.bn2.weight, backbone.layer2.0.bn2.bias, backbone.layer2.0.bn2.running_mean, backbone.layer2.0.bn2.running_var, backbone.layer2.0.bn2.num_batches_tracked, backbone.layer2.0.conv3.weight, backbone.layer2.0.bn3.weight, backbone.layer2.0.bn3.bias, backbone.layer2.0.bn3.running_mean, backbone.layer2.0.bn3.running_var, backbone.layer2.0.bn3.num_batches_tracked, backbone.layer2.0.downsample.0.weight, backbone.layer2.0.downsample.1.weight, backbone.layer2.0.downsample.1.bias, backbone.layer2.0.downsample.1.running_mean, backbone.layer2.0.downsample.1.running_var, backbone.layer2.0.downsample.1.num_batches_tracked, backbone.layer2.1.conv1.weight, backbone.layer2.1.bn1.weight, backbone.layer2.1.bn1.bias, backbone.layer2.1.bn1.running_mean, backbone.layer2.1.bn1.running_var, backbone.layer2.1.bn1.num_batches_tracked, backbone.layer2.1.conv2.weight, backbone.layer2.1.bn2.weight, backbone.layer2.1.bn2.bias, backbone.layer2.1.bn2.running_mean, backbone.layer2.1.bn2.running_var, backbone.layer2.1.bn2.num_batches_tracked, backbone.layer2.1.conv3.weight, backbone.layer2.1.bn3.weight, backbone.layer2.1.bn3.bias, backbone.layer2.1.bn3.running_mean, backbone.layer2.1.bn3.running_var, backbone.layer2.1.bn3.num_batches_tracked, backbone.layer2.2.conv1.weight, backbone.layer2.2.bn1.weight, backbone.layer2.2.bn1.bias, backbone.layer2.2.bn1.running_mean, backbone.layer2.2.bn1.running_var, backbone.layer2.2.bn1.num_batches_tracked, backbone.layer2.2.conv2.weight, backb ...
#
# missing keys in source state_dict: fc.weight, fc.bias
#
# 06/10 13:36:23 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 06/10 13:36:23 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 06/10 13:36:23 - mmengine - INFO - Checkpoints will be saved to /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/fruit30_exp.
# 06/10 13:36:54 - mmengine - INFO - Exp name: resnet50_fruits_20230610_133600
# 06/10 13:36:54 - mmengine - INFO - Epoch(train)  [1][97/97]  lr: 1.0000e-02  eta: 0:09:56  time: 0.2949  data_time: 0.0004  memory: 2962  loss: 2.6786
# 06/10 13:36:54 - mmengine - INFO - Saving checkpoint at 1 epochs
# 06/10 13:37:00 - mmengine - INFO - Epoch(val) [1][41/41]    accuracy/top1: 23.2074  accuracy/top5: 66.9237  data_time: 0.0109  time: 0.0924
# 06/10 13:37:01 - mmengine - INFO - The best checkpoint with 23.2074 accuracy/top1 at 1 epoch is saved to best_accuracy_top1_epoch_1.pth.
# 06/10 13:37:32 - mmengine - INFO - Exp name: resnet50_fruits_20230610_133600
# 06/10 13:37:32 - mmengine - INFO - Epoch(train)  [2][97/97]  lr: 1.0000e-02  eta: 0:09:26  time: 0.3476  data_time: 0.0004  memory: 2962  loss: 2.4346
# 06/10 13:37:32 - mmengine - INFO - Saving checkpoint at 2 epochs
# 06/10 13:37:39 - mmengine - INFO - Epoch(val) [2][41/41]    accuracy/top1: 31.6885  accuracy/top5: 71.1642  data_time: 0.0035  time: 0.0846
# 06/10 13:37:39 - mmengine - INFO - The previous best checkpoint /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/fruit30_exp/best_accuracy_top1_epoch_1.pth is removed
# 06/10 13:37:40 - mmengine - INFO - The best checkpoint with 31.6885 accuracy/top1 at 2 epoch is saved to best_accuracy_top1_epoch_2.pth.
# 06/10 13:38:11 - mmengine - INFO - Exp name: resnet50_fruits_20230610_133600
# 06/10 13:38:11 - mmengine - INFO - Epoch(train)  [3][97/97]  lr: 1.0000e-02  eta: 0:08:55  time: 0.3025  data_time: 0.0004  memory: 2962  loss: 2.4011
# 06/10 13:38:11 - mmengine - INFO - Saving checkpoint at 3 epochs
# 06/10 13:38:16 - mmengine - INFO - Epoch(val) [3][41/41]    accuracy/top1: 33.2305  accuracy/top5: 77.5636  data_time: 0.0027  time: 0.0827
# 06/10 13:38:16 - mmengine - INFO - The previous best checkpoint /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/fruit30_exp/best_accuracy_top1_epoch_2.pth is removed
# 06/10 13:38:17 - mmengine - INFO - The best checkpoint with 33.2305 accuracy/top1 at 3 epoch is saved to best_accuracy_top1_epoch_3.pth.
# 06/10 13:38:52 - mmengine - INFO - Exp name: resnet50_fruits_20230610_133600
# 06/10 13:38:52 - mmengine - INFO - Epoch(train)  [4][97/97]  lr: 1.0000e-02  eta: 0:08:38  time: 0.3039  data_time: 0.0005  memory: 2962  loss: 2.2661
# 06/10 13:38:52 - mmengine - INFO - Saving checkpoint at 4 epochs
# 06/10 13:38:58 - mmengine - INFO - Epoch(val) [4][41/41]    accuracy/top1: 32.9221  accuracy/top5: 75.8674  data_time: 0.0032  time: 0.0851
# 06/10 13:39:30 - mmengine - INFO - Exp name: resnet50_fruits_20230610_133600
# 06/10 13:39:30 - mmengine - INFO - Epoch(train)  [5][97/97]  lr: 1.0000e-02  eta: 0:08:04  time: 0.3066  data_time: 0.0005  memory: 2962  loss: 2.2121
# 06/10 13:39:30 - mmengine - INFO - Saving checkpoint at 5 epochs
# 06/10 13:39:45 - mmengine - INFO - Epoch(val) [5][41/41]    accuracy/top1: 38.3192  accuracy/top5: 79.7224  data_time: 0.0736  time: 0.3121
# 06/10 13:39:45 - mmengine - INFO - The previous best checkpoint /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/fruit30_exp/best_accuracy_top1_epoch_3.pth is removed
# 06/10 13:39:50 - mmengine - INFO - The best checkpoint with 38.3192 accuracy/top1 at 5 epoch is saved to best_accuracy_top1_epoch_5.pth.
# 06/10 13:40:22 - mmengine - INFO - Exp name: resnet50_fruits_20230610_133600
# 06/10 13:40:22 - mmengine - INFO - Epoch(train)  [6][97/97]  lr: 1.0000e-02  eta: 0:07:32  time: 0.3054  data_time: 0.0005  memory: 2962  loss: 1.9839
# 06/10 13:40:22 - mmengine - INFO - Saving checkpoint at 6 epochs
# 06/10 13:40:27 - mmengine - INFO - Epoch(val) [6][41/41]    accuracy/top1: 36.8543  accuracy/top5: 81.4187  data_time: 0.0028  time: 0.0855
# 06/10 13:40:59 - mmengine - INFO - Exp name: resnet50_fruits_20230610_133600
# 06/10 13
- mmengine - INFO - Exp name: resnet50_fruits_20230610_133600
# 06/10 13:48:32 - mmengine - INFO - Epoch(train) [19][97/97]  lr: 1.0000e-02  eta: 0:00:32  time: 0.3105  data_time: 0.0005  memory: 2962  loss: 1.6516
# 06/10 13:48:32 - mmengine - INFO - Saving checkpoint at 19 epochs
# 06/10 13:48:37 - mmengine - INFO - Epoch(val) [19][41/41]    accuracy/top1: 49.2675  accuracy/top5: 85.7363  data_time: 0.0028  time: 0.0855
# 06/10 13:48:37 - mmengine - INFO - The previous best checkpoint /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/fruit30_exp/best_accuracy_top1_epoch_12.pth is removed
# 06/10 13:48:38 - mmengine - INFO - The best checkpoint with 49.2675 accuracy/top1 at 19 epoch is saved to best_accuracy_top1_epoch_19.pth.
# 06/10 13:49:10 - mmengine - INFO - Exp name: resnet50_fruits_20230610_133600
# 06/10 13:49:10 - mmengine - INFO - Epoch(train) [20][97/97]  lr: 1.0000e-02  eta: 0:00:00  time: 0.3102  data_time: 0.0005  memory: 2962  loss: 1.9225
# 06/10 13:49:10 - mmengine - INFO - Saving checkpoint at 20 epochs
# 06/10 13:49:15 - mmengine - INFO - Epoch(val) [20][41/41]    accuracy/top1: 50.2699  accuracy/top5: 86.8157  data_time: 0.0027  time: 0.0851
# 06/10 13:49:15 - mmengine - INFO - The previous best checkpoint /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/fruit30_exp/best_accuracy_top1_epoch_19.pth is removed
# 06/10 13:49:16 - mmengine - INFO - The best checkpoint with 50.2699 accuracy/top1 at 20 epoch is saved to best_accuracy_top1_epoch_20.pth.
# Training finished successfully.

# %% [markdown]
# ## 测试集表现

# %%
#在测试集测试，看准确率
# !mim test mmpretrain projects/fruits/resnet50_fruits.py --checkpoint fruit30_exp/best_accuracy_top1_epoch_20.pth
# Out:
# Testing command is /root/miniconda3/bin/python /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/test.py projects/fruits/resnet50_fruits.py fruit30_exp/best_accuracy_top1_epoch_20.pth --launcher none.
# 06/10 13:53:28 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 517774577
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
#     PyTorch: 1.10.0+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.2
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.11.1+cu113
#     OpenCV: 4.7.0
#     MMEngine: 0.7.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/10 13:53:28 - mmengine - INFO - Config:
# model = dict(
#     type='ImageClassifier',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch'),
#     neck=dict(type='GlobalAveragePooling'),
#     head=dict(
#         type='LinearClsHead',
#         num_classes=30,
#         in_channels=2048,
#         loss=dict(type='CrossEntropyLoss', loss_weight=1.0),
#         topk=(1, 5),
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth'
#         )))
# dataset_type = 'CustomDataset'
# data_preprocessor = dict(
#     num_classes=1000,
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='RandomResizedCrop', scale=224),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='ResizeEdge', scale=256, edge='short'),
#     dict(type='CenterCrop', crop_size=224),
#     dict(type='PackInputs')
# ]
# train_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='RandomResizedCrop', scale=224),
#             dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=True))
# val_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_test',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# val_evaluator = dict(type='Accuracy', topk=(1, 5))
# test_dataloader = dict(
#     pin_memory=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_test',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# test_evaluator = dict(type='Accuracy', topk=(1, 5))
# optim_wrapper = dict(
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0001))
# param_scheduler = dict(
#     type='MultiStepLR', by_epoch=True, milestones=[30, 60, 90], gamma=0.1)
# train_cfg = dict(by_epoch=True, max_epochs=20, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# auto_scale_lr = dict(base_batch_size=256)
# default_scope = 'mmpretrain'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook', interval=1, max_keep_ckpts=5, save_best='auto'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='VisualizationHook', enable=False))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='UniversalVisualizer', vis_backends=[dict(type='LocalVisBackend')])
# log_level = 'INFO'
# load_from = 'fruit30_exp/best_accuracy_top1_epoch_20.pth'
# resume = False
# randomness = dict(seed=None, deterministic=False)
# launcher = 'none'
# work_dir = './work_dirs/resnet50_fruits'
#
# 06/10 13:53:36 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/10 13:53:36 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# Loads checkpoint by local backend from path: fruit30_exp/best_accuracy_top1_epoch_20.pth
# 06/10 13:53:38 - mmengine - INFO - Load checkpoint from fruit30_exp/best_accuracy_top1_epoch_20.pth
# 06/10 13:53:42 - mmengine - INFO - Epoch(test) [41/41]    accuracy/top1: 50.2699  accuracy/top5: 86.8157  data_time: 0.0103  time: 0.0918
# Testing finished successfully.

# %%
#把每个样本的测试结果全都保存在result.pkl文件里
# !mim test mmpretrain projects/fruits/resnet50_fruits.py --checkpoint fruit30_exp/best_accuracy_top1_epoch_20.pth --out result.pkl
# Out:
# Testing command is /root/miniconda3/bin/python /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/test.py projects/fruits/resnet50_fruits.py fruit30_exp/best_accuracy_top1_epoch_20.pth --launcher none --out result.pkl.
# 06/10 14:02:36 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 1179554412
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
#     PyTorch: 1.10.0+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.2
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.11.1+cu113
#     OpenCV: 4.7.0
#     MMEngine: 0.7.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/10 14:02:36 - mmengine - INFO - Config:
# model = dict(
#     type='ImageClassifier',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch'),
#     neck=dict(type='GlobalAveragePooling'),
#     head=dict(
#         type='LinearClsHead',
#         num_classes=30,
#         in_channels=2048,
#         loss=dict(type='CrossEntropyLoss', loss_weight=1.0),
#         topk=(1, 5),
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth'
#         )))
# dataset_type = 'CustomDataset'
# data_preprocessor = dict(
#     num_classes=1000,
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='RandomResizedCrop', scale=224),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='ResizeEdge', scale=256, edge='short'),
#     dict(type='CenterCrop', crop_size=224),
#     dict(type='PackInputs')
# ]
# train_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='RandomResizedCrop', scale=224),
#             dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=True))
# val_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_test',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# val_evaluator = dict(type='Accuracy', topk=(1, 5))
# test_dataloader = dict(
#     pin_memory=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_test',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# test_evaluator = dict(type='Accuracy', topk=(1, 5))
# optim_wrapper = dict(
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0001))
# param_scheduler = dict(
#     type='MultiStepLR', by_epoch=True, milestones=[30, 60, 90], gamma=0.1)
# train_cfg = dict(by_epoch=True, max_epochs=20, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# auto_scale_lr = dict(base_batch_size=256)
# default_scope = 'mmpretrain'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook', interval=1, max_keep_ckpts=5, save_best='auto'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='VisualizationHook', enable=False))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='UniversalVisualizer', vis_backends=[dict(type='LocalVisBackend')])
# log_level = 'INFO'
# load_from = 'fruit30_exp/best_accuracy_top1_epoch_20.pth'
# resume = False
# randomness = dict(seed=None, deterministic=False)
# launcher = 'none'
# work_dir = './work_dirs/resnet50_fruits'
#
# 06/10 14:02:44 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/10 14:02:44 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 06/10 14:02:45 - mmengine - WARNING - The prefix is not set in metric class DumpResults.
# Loads checkpoint by local backend from path: fruit30_exp/best_accuracy_top1_epoch_20.pth
# 06/10 14:02:46 - mmengine - INFO - Load checkpoint from fruit30_exp/best_accuracy_top1_epoch_20.pth
# 06/10 14:02:50 - mmengine - INFO - Results has been saved to result.pkl.
# 06/10 14:02:50 - mmengine - INFO - Epoch(test) [41/41]    accuracy/top1: 50.2699  accuracy/top5: 86.8157  data_time: 0.0102  time: 0.0915
# Testing finished successfully.

# %%
#绘制分类混淆矩阵
# !mim run mmpretrain confusion_matrix projects/fruits/resnet50_fruits.py result.pkl --show-path workout/fruit30_confusion_matrix.jpg
# Out:
# Use the script /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py for command confusion_matrix.
# The command to call is /root/miniconda3/bin/python /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py projects/fruits/resnet50_fruits.py result.pkl --show-path workout/fruit30_confusion_matrix.jpg.
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 21704 (\N{CJK UNIFIED IDEOGRAPH-54C8}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 23494 (\N{CJK UNIFIED IDEOGRAPH-5BC6}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 29916 (\N{CJK UNIFIED IDEOGRAPH-74DC}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 22307 (\N{CJK UNIFIED IDEOGRAPH-5723}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 22899 (\N{CJK UNIFIED IDEOGRAPH-5973}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 26524 (\N{CJK UNIFIED IDEOGRAPH-679C}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 23665 (\N{CJK UNIFIED IDEOGRAPH-5C71}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 31481 (\N{CJK UNIFIED IDEOGRAPH-7AF9}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 26472 (\N{CJK UNIFIED IDEOGRAPH-6768}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 26757 (\N{CJK UNIFIED IDEOGRAPH-6885}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 26586 (\N{CJK UNIFIED IDEOGRAPH-67DA}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 23376 (\N{CJK UNIFIED IDEOGRAPH-5B50}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 26592 (\N{CJK UNIFIED IDEOGRAPH-67E0}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 27308 (\N{CJK UNIFIED IDEOGRAPH-6AAC}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 26690 (\N{CJK UNIFIED IDEOGRAPH-6842}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 22278 (\N{CJK UNIFIED IDEOGRAPH-5706}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 26792 (\N{CJK UNIFIED IDEOGRAPH-68A8}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 26928 (\N{CJK UNIFIED IDEOGRAPH-6930}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 27060 (\N{CJK UNIFIED IDEOGRAPH-69B4}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 33714 (\N{CJK UNIFIED IDEOGRAPH-83B2}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 28779 (\N{CJK UNIFIED IDEOGRAPH-706B}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 40857 (\N{CJK UNIFIED IDEOGRAPH-9F99}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 29461 (\N{CJK UNIFIED IDEOGRAPH-7315}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 29492 (\N{CJK UNIFIED IDEOGRAPH-7334}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 26691 (\N{CJK UNIFIED IDEOGRAPH-6843}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 30707 (\N{CJK UNIFIED IDEOGRAPH-77F3}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 30722 (\N{CJK UNIFIED IDEOGRAPH-7802}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 31958 (\N{CJK UNIFIED IDEOGRAPH-7CD6}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 27224 (\N{CJK UNIFIED IDEOGRAPH-6A58}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 32993 (\N{CJK UNIFIED IDEOGRAPH-80E1}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 33821 (\N{CJK UNIFIED IDEOGRAPH-841D}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 21340 (\N{CJK UNIFIED IDEOGRAPH-535C}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 33040 (\N{CJK UNIFIED IDEOGRAPH-8110}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 27225 (\N{CJK UNIFIED IDEOGRAPH-6A59}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 33426 (\N{CJK UNIFIED IDEOGRAPH-8292}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 33510 (\N{CJK UNIFIED IDEOGRAPH-82E6}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 33529 (\N{CJK UNIFIED IDEOGRAPH-82F9}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 32418 (\N{CJK UNIFIED IDEOGRAPH-7EA2}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 38738 (\N{CJK UNIFIED IDEOGRAPH-9752}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 33609 (\N{CJK UNIFIED IDEOGRAPH-8349}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 33683 (\N{CJK UNIFIED IDEOGRAPH-8393}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 33620 (\N{CJK UNIFIED IDEOGRAPH-8354}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 26525 (\N{CJK UNIFIED IDEOGRAPH-679D}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 33760 (\N{CJK UNIFIED IDEOGRAPH-83E0}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 33889 (\N{CJK UNIFIED IDEOGRAPH-8461}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 33796 (\N{CJK UNIFIED IDEOGRAPH-8404}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 30333 (\N{CJK UNIFIED IDEOGRAPH-767D}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 35199 (\N{CJK UNIFIED IDEOGRAPH-897F}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 26623 (\N{CJK UNIFIED IDEOGRAPH-67FF}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 36710 (\N{CJK UNIFIED IDEOGRAPH-8F66}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 21400 (\N{CJK UNIFIED IDEOGRAPH-5398}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 39321 (\N{CJK UNIFIED IDEOGRAPH-9999}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 34121 (\N{CJK UNIFIED IDEOGRAPH-8549}) missing from current font.
#   fig.savefig(args.show_path)
# /root/autodl-tmp/pythonProject/openmmlab_ai/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py:103: UserWarning: Glyph 40644 (\N{CJK UNIFIED IDEOGRAPH-9EC4}) missing from current font.
#   fig.savefig(args.show_path)
# The confusion matrix is saved at workout/fruit30_confusion_matrix.jpg.
# The script finished successfully.

# %% [markdown]
# ## 推理

# %%
#用训练好的模型，在真实图片上推理
from mmpretrain import ImageClassificationInferencer

inferencer = ImageClassificationInferencer('projects/fruits/resnet50_fruits.py',pretrained='fruit30_exp/best_accuracy_top1_epoch_20.pth')
# Out:
# Loads checkpoint by local backend from path: fruit30_exp/best_accuracy_top1_epoch_20.pth

# %%
inferencer('data/banana.jpg',show_dir='workout')
# Out:
# 06/10 14:14:52 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /root/miniconda3/lib/python3.8/site-packages/mmengine/visualization/utils.py:240: UserWarning: Glyph 39321 (\N{CJK
# UNIFIED IDEOGRAPH-9999}) missing from current font.
#   s, (width, height) = canvas.print_to_buffer()
# /root/miniconda3/lib/python3.8/site-packages/mmengine/visualization/utils.py:240: UserWarning: Glyph 34121 (\N{CJK
# UNIFIED IDEOGRAPH-8549}) missing from current font.
#   s, (width, height) = canvas.print_to_buffer()
# [{'pred_scores': array([7.7818115e-03, 2.1327134e-05, 2.8854784e-05, 4.0901905e-05,
#          2.6766530e-01, 4.3212190e-02, 2.1572720e-04, 4.7429059e-02,
#          2.9062369e-04, 3.3140533e-02, 6.4646476e-05, 3.3446802e-03,
#          4.6656591e-05, 3.0109870e-06, 2.4170993e-06, 3.3085412e-04,
#          2.5253281e-01, 6.3996260e-05, 1.5210581e-04, 2.5561755e-04,
#          2.3025618e-06, 6.4287460e-06, 5.7442030e-03, 1.4152870e-03,
#          3.7764942e-06, 3.0659189e-04, 1.0918127e-05, 3.5548430e-05,
#          3.3581299e-01, 3.8779956e-05], dtype=float32),
#   'pred_label': 28,
#   'pred_score': 0.3358129858970642,
#   'pred_class': '香蕉'}]
